# %% [markdown]
# ## Case Study #1
# สาเหตุการเสียชีวิตส่วนใหญ่ของชาวอเมริกันระหว่างปี คศ. 1999 - 2017

# %%
from google.colab import files
files.upload() # upload file NCHS1.csv
# Out:
#      <input type="file" id="files-f6dc6c12-fd28-4c5e-85f8-666d5586c98e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6dc6c12-fd28-4c5e-85f8-666d5586c98e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NCHS1.csv to NCHS1.csv
# {'NCHS1.csv': b'Year,113 Cause Name,Cause Name,State,Deaths,Age-adjusted Death Rate\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,United States,169936,49.4\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Alabama,2703,53.8\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Alaska,436,63.7\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Arizona,4184,56.2\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Arkansas,1625,51.8\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,California,13840,33.2\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Colorado,3037,53.6\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Connecticut,2078,53.2\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Delaware,608,61.9\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,District of Columbia,427,61.0\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Florida,13059,56.1\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Georgia,4712,45.2\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Hawaii,585,35.7\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Idaho,876,49.8\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Illinois,6019,44.4\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Indiana,3978,58.7\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Iowa,1536,42.8\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Kansas,1567,49.4\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Kentucky,3264,72.9\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Louisiana,2780,58.9\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Maine,990,68.0\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Maryland,2408,36.9\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Massachusetts,3821,51.5\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Michigan,5623,53.0\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Minnesota,2788,44.6\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Mississippi,1738,56.3\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Missouri,3776,58.8\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Montana,579,50.2\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Nebraska,811,38.5\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Nevada,1496,47.8\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New Hampshire,907,62.9\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New Jersey,4482,47.3\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New Mexico,1460,68.3\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New York,7687,35.5\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,North Carolina,5985,56.3\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,North Dakota,339,41.3\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Ohio,8971,75.1\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Okla ...

# %%
import pandas as pd

df = pd.read_csv('NCHS1.csv')

display(df.head(5),
        df.tail(5))
# Out:
#    Year  ... Age-adjusted Death Rate
# 0  2017  ...                    49.4
# 1  2017  ...                    53.8
# 2  2017  ...                    63.7
# 3  2017  ...                    56.2
# 4  2017  ...                    51.8
#
# [5 rows x 6 columns]
#        Year  ... Age-adjusted Death Rate
# 10863  1999  ...                    16.9
# 10864  1999  ...                     5.2
# 10865  1999  ...                    16.4
# 10866  1999  ...                    11.9
# 10867  1999  ...                     6.8
#
# [5 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10868 entries, 0 to 10867
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10868 non-null  int64
#  1   113 Cause Name           10868 non-null  object
#  2   Cause Name               10868 non-null  object
#  3   State                    10868 non-null  object
#  4   Deaths                   10868 non-null  int64
#  5   Age-adjusted Death Rate  10868 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 509.6+ KB

# %%
import pandas as pd

df = pd.read_csv('NCHS1.csv')

print(df['Cause Name'].unique(),
      df['State'].unique(),
      sep='\n\n')
# Out:
# ['Unintentional injuries' 'All causes' "Alzheimer's disease" 'Stroke'
#  'CLRD' 'Diabetes' 'Heart disease' 'Influenza and pneumonia' 'Suicide'
#  'Cancer' 'Kidney disease']
#
# ['United States' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'North Carolina'
#  'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island'
#  'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont'
#  'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
import pandas as pd

df = pd.read_csv('NCHS1.csv')
print('Old file', df.shape)

df2 = df[df['Cause Name'] != 'All causes']
df3 = df2[df2['State'] != 'United States']

df3.to_csv('NCHS2.csv', index=None)
print('New file', df3.shape)
# Out:
# Old file (10868, 6)
# New file (9690, 6)

# %%
from google.colab import files
files.upload() # upload file NCHS2.csv
# Out:
#      <input type="file" id="files-4ac8c898-9fc9-49d4-928c-d89469ad37e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ac8c898-9fc9-49d4-928c-d89469ad37e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NCHS2.csv to NCHS2.csv
# {'NCHS2.csv': b'Year,113 Cause Name,Cause Name,State,Deaths,Age-adjusted Death Rate\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Alabama,2703,53.8\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Alaska,436,63.7\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Arizona,4184,56.2\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Arkansas,1625,51.8\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,California,13840,33.2\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Colorado,3037,53.6\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Connecticut,2078,53.2\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Delaware,608,61.9\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,District of Columbia,427,61.0\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Florida,13059,56.1\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Georgia,4712,45.2\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Hawaii,585,35.7\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Idaho,876,49.8\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Illinois,6019,44.4\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Indiana,3978,58.7\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Iowa,1536,42.8\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Kansas,1567,49.4\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Kentucky,3264,72.9\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Louisiana,2780,58.9\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Maine,990,68.0\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Maryland,2408,36.9\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Massachusetts,3821,51.5\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Michigan,5623,53.0\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Minnesota,2788,44.6\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Mississippi,1738,56.3\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Missouri,3776,58.8\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Montana,579,50.2\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Nebraska,811,38.5\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Nevada,1496,47.8\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New Hampshire,907,62.9\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New Jersey,4482,47.3\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New Mexico,1460,68.3\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,New York,7687,35.5\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,North Carolina,5985,56.3\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,North Dakota,339,41.3\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Ohio,8971,75.1\r\n2017,"Accidents (unintentional injuries) (V01-X59,Y85-Y86)",Unintentional injuries,Oklahoma,2563,62.5\r\n2017,"Accidents (u ...

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

print(df['Cause Name'].unique(), 
      df['State'].unique(), 
      sep='\n\n')
# Out:
# ['Unintentional injuries' "Alzheimer's disease" 'Stroke' 'CLRD' 'Diabetes'
#  'Heart disease' 'Influenza and pneumonia' 'Suicide' 'Cancer'
#  'Kidney disease']
#
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

sum = df['Deaths'].sum()
sum_fm = format(sum, ',')

print('Total deaths:', sum_fm)
# Out:
# Total deaths: 36,280,583

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

df_ca = df[(df.Year == 2017) & (df.State == 'California')]

df_ca
# Out:
#      Year  ... Age-adjusted Death Rate
# 4    2017  ...                    33.2
# 55   2017  ...                    37.1
# 106  2017  ...                    37.6
# 157  2017  ...                    32.2
# 208  2017  ...                    22.1
# 259  2017  ...                   142.9
# 310  2017  ...                    14.6
# 361  2017  ...                    10.5
# 412  2017  ...                   136.8
# 463  2017  ...                     8.9
#
# [10 rows x 6 columns]

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

df_diabetes = df[df['Cause Name'] == 'Diabetes']
sum_diabetes = df_diabetes['Deaths'].sum()

#หรือเขียนรวมในขั้นตอนเดียวเป็น
#sum_diabetes_sum = df[df['Cause Name'] == 'Diabetes']['Deaths'].sum()

print('Total deaths of diabetes :', format(sum_diabetes, ','))

suicide_2015_2017 = df[(df['Cause Name'] == 'Suicide') &
                       (df['Year'] >= 2015) & (df['Year'] <= 2017)]

sum_suicide = suicide_2015_2017['Deaths'].sum()

print('Total deaths of suicide between 2015-2017 :', 
      format(sum_suicide, ','))
# Out:
# Total deaths of diabetes : 1,399,943
# Total deaths of suicide between 2015-2017 : 136,331

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

df = df[df.Year >= 2010].groupby('Year').sum()

df[['Deaths']].style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >Year</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row0" class="row_heading level0 row0" >2010</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row0_col0" class="data row0 col0" >1,852,349</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row1" class="row_heading level0 row1" >2011</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row1_col0" class="data row1 col0" >1,869,321</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row2" class="row_heading level0 row2" >2012</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row2_col0" class="data row2 col0" >1,876,588</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row3" class="row_heading level0 row3" >2013</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row3_col0" class="data row3 col0" >1,910,311</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row4" class="row_heading level0 row4" >2014</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row4_col0" class="data row4 col0" >1,938,408</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row5" class="row_heading level0 row5" >2015</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row5_col0" class="data row5 col0" >2,013,017</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row6" class="row_heading level0 row6" >2016</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row6_col0" class="data row6 col0" >2,034,119</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002level0_row7" class="row_heading level0 row7" >2017</th>
#                         <td id="T_60a3f7e0_fe60_11ea_916c_0242ac1c0002row7_col0" class="data row7 col0" >2,081,531</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

df = df.groupby('State').sum().sort_values(by='Deaths', ascending=False)

df[['Deaths']].head(10).style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_a10dd558_fe60_11ea_916c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >State</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row0" class="row_heading level0 row0" >California</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row0_col0" class="data row0 col0" >3,594,261</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row1" class="row_heading level0 row1" >Florida</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row1_col0" class="data row1 col0" >2,533,472</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row2" class="row_heading level0 row2" >Texas</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row2_col0" class="data row2 col0" >2,367,695</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row3" class="row_heading level0 row3" >New York</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row3_col0" class="data row3 col0" >2,264,120</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row4" class="row_heading level0 row4" >Pennsylvania</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row4_col0" class="data row4 col0" >1,854,953</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row5" class="row_heading level0 row5" >Ohio</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row5_col0" class="data row5 col0" >1,605,250</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row6" class="row_heading level0 row6" >Illinois</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row6_col0" class="data row6 col0" >1,508,039</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row7" class="row_heading level0 row7" >Michigan</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row7_col0" class="data row7 col0" >1,313,813</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row8" class="row_heading level0 row8" >North Carolina</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row8_col0" class="data row8 col0" >1,115,953</td>
#             </tr>
#             <tr>
#                         <th id="T_a10dd558_fe60_11ea_916c_0242ac1c0002level0_row9" class="row_heading level0 row9" >New Jersey</th>
#                         <td id="T_a10dd558_fe60_11ea_916c_0242ac1c0002row9_col0" class="data row9 col0" >1,030,622</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

df = df.groupby(['Cause Name']).sum().sort_values(by='Deaths', 
                                                  ascending=False)

df[['Deaths']].style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >Cause Name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >Heart disease</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >12,222,640</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row1" class="row_heading level0 row1" >Cancer</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >10,843,644</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row2" class="row_heading level0 row2" >Stroke</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >2,726,523</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" >CLRD</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >2,594,927</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row4" class="row_heading level0 row4" >Unintentional injuries</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >2,347,820</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row5" class="row_heading level0 row5" >Alzheimer's disease</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >1,494,816</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" >Diabetes</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >1,399,943</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row7" class="row_heading level0 row7" >Influenza and pneumonia</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >1,094,641</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row8" class="row_heading level0 row8" >Kidney disease</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >858,613</td>
#             </tr>
#             <tr>
#                         <th id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002level0_row9" class="row_heading level0 row9" >Suicide</th>
#                         <td id="T_c2b2ac00_fe43_11ea_8cfd_0242ac1c0002row9_col0" class="data row9 col0" >697,016</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('NCHS2.csv')

#กำหนดเงื่อนไขโดยเลือกเฉพาะข้อมูลของรัฐ Florida ตั้งแต่ปี 2015 เป็นต้นมา
df_fl = df[(df.Year >= 2015) & (df.State == 'Florida')]

#เรียงลำดับข้อมูลจากมากไปหาน้อย
df_fl = df_fl.sort_values(by='Deaths', ascending=False)

#แบ่งกลุ่มตามปีค.ศ. แล้วเลือกข้อมูล 3 ลำดับแรกของแต่ละกลุ่ม
df_fl = df_fl.groupby(['Year']).head(3)

#display(df_fl)

#จัดกลุ่มอีกครั้ง โดยใช้ปีและสาเหตุการเสียชีวิตในการจัดกลุ่ม
#แล้วแสดงผลรวมของแต่ละกลุ่ม ในแบบ Aggregate Function 
#เพื่อหาผลรวมเฉพาะคอลัมน์ Deaths 
#g = df_fl.groupby(['Year', 'Cause Name']).agg({'Deaths':sum})

#หรือแบบนี้ก็ได้
g = df_fl.groupby(['Year', 'Cause Name'])[['Deaths']].sum()

g.style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Deaths</th>    </tr>    <tr>        <th class="index_name level0" >Year</th>        <th class="index_name level1" >Cause Name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>2015</th>
#                         <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row0" class="row_heading level1 row0" >CLRD</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row0_col0" class="data row0 col0" >11,705</td>
#             </tr>
#             <tr>
#                                 <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row1" class="row_heading level1 row1" >Cancer</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row1_col0" class="data row1 col0" >44,027</td>
#             </tr>
#             <tr>
#                                 <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row2" class="row_heading level1 row2" >Heart disease</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row2_col0" class="data row2 col0" >45,441</td>
#             </tr>
#             <tr>
#                         <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level0_row3" class="row_heading level0 row3" rowspan=3>2016</th>
#                         <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row3" class="row_heading level1 row3" >Cancer</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row3_col0" class="data row3 col0" >44,266</td>
#             </tr>
#             <tr>
#                                 <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row4" class="row_heading level1 row4" >Heart disease</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row4_col0" class="data row4 col0" >45,659</td>
#             </tr>
#             <tr>
#                                 <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row5" class="row_heading level1 row5" >Unintentional injuries</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row5_col0" class="data row5 col0" >12,561</td>
#             </tr>
#             <tr>
#                         <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level0_row6" class="row_heading level0 row6" rowspan=3>2017</th>
#                         <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row6" class="row_heading level1 row6" >Cancer</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row6_col0" class="data row6 col0" >45,131</td>
#             </tr>
#             <tr>
#                                 <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row7" class="row_heading level1 row7" >Heart disease</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row7_col0" class="data row7 col0" >46,440</td>
#             </tr>
#             <tr>
#                                 <th id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002level1_row8" class="row_heading level1 row8" >Unintentional injuries</th>
#                         <td id="T_afcfefd6_fe60_11ea_916c_0242ac1c0002row8_col0" class="data row8 col0" >13,059</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

df = pd.read_csv('NCHS2.csv')
df = df[df.Year >= 2010].groupby('Year').sum()

plt.plot(df.index, df['Deaths'], 'ro-')
plt.show()

#df[['Deaths']].plot(kind='line', style='ro-')

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

df = pd.read_csv('NCHS2.csv')

df = df[(df.Year >= 2008) & (df['Cause Name'] == 'Kidney disease')]
df = df.groupby('Year').sum()

plt.plot(df.index, df['Deaths'], 'mD-')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')

df = pd.read_csv('NCHS2.csv')

df = df[df.State == 'California'].groupby('Cause Name').sum()

#display(df)

df[['Deaths']].plot.bar(color='y')

# %% [markdown]
# # **Case Study 2**
# ข้อมูลประเทศทั่วโลก

# %%
from google.colab import files
files.upload() # upload file
# Out:
#      <input type="file" id="files-0bacaa70-5625-472e-9439-c5b6dcc301e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bacaa70-5625-472e-9439-c5b6dcc301e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving countries_info.csv to countries_info.csv
# {'countries_info.csv': b'Country,Region,Population,Area_sq_mi,GDP_USD_per_capita\r\nAfghanistan,ASIA (EX. NEAR EAST),31056997,647500,700.0\r\nAlbania,EASTERN EUROPE,3581655,28748,4500.0\r\nAlgeria,NORTHERN AFRICA,32930091,2381740,6000.0\r\nAmerican Samoa,OCEANIA,57794,199,8000.0\r\nAndorra,WESTERN EUROPE,71201,468,19000.0\r\nAngola,SUB-SAHARAN AFRICA,12127071,1246700,1900.0\r\nAnguilla,LATIN AMER. & CARIB,13477,102,8600.0\r\nAntigua & Barbuda,LATIN AMER. & CARIB,69108,443,11000.0\r\nArgentina,LATIN AMER. & CARIB,39921833,2766890,11200.0\r\nArmenia,C.W. OF IND. STATES,2976372,29800,3500.0\r\nAruba,LATIN AMER. & CARIB,71891,193,28000.0\r\nAustralia,OCEANIA,20264082,7686850,29000.0\r\nAustria,WESTERN EUROPE,8192880,83870,30000.0\r\nAzerbaijan,C.W. OF IND. STATES,7961619,86600,3400.0\r\n"Bahamas, The",LATIN AMER. & CARIB,303770,13940,16700.0\r\nBahrain,NEAR EAST,698585,665,16900.0\r\nBangladesh,ASIA (EX. NEAR EAST),147365352,144000,1900.0\r\nBarbados,LATIN AMER. & CARIB,279912,431,15700.0\r\nBelarus,C.W. OF IND. STATES,10293011,207600,6100.0\r\nBelgium,WESTERN EUROPE,10379067,30528,29100.0\r\nBelize,LATIN AMER. & CARIB,287730,22966,4900.0\r\nBenin,SUB-SAHARAN AFRICA,7862944,112620,1100.0\r\nBermuda,NORTHERN AMERICA,65773,53,36000.0\r\nBhutan,ASIA (EX. NEAR EAST),2279723,47000,1300.0\r\nBolivia,LATIN AMER. & CARIB,8989046,1098580,2400.0\r\nBosnia & Herzegovina,EASTERN EUROPE,4498976,51129,6100.0\r\nBotswana,SUB-SAHARAN AFRICA,1639833,600370,9000.0\r\nBrazil,LATIN AMER. & CARIB,188078227,8511965,7600.0\r\nBritish Virgin Is.,LATIN AMER. & CARIB,23098,153,16000.0\r\nBrunei,ASIA (EX. NEAR EAST),379444,5770,18600.0\r\nBulgaria,EASTERN EUROPE,7385367,110910,7600.0\r\nBurkina Faso,SUB-SAHARAN AFRICA,13902972,274200,1100.0\r\nBurma,ASIA (EX. NEAR EAST),47382633,678500,1800.0\r\nBurundi,SUB-SAHARAN AFRICA,8090068,27830,600.0\r\nCambodia,ASIA (EX. NEAR EAST),13881427,181040,1900.0\r\nCameroon,SUB-SAHARAN AFRICA,17340702,475440,1800.0\r\nCanada,NORTHERN AMERICA,33098932,9984670,29800.0\r\nCape Verde,SUB-SAHARAN AFRICA,420979,4033,1400.0\r\nCayman Islands,LATIN AMER. & CARIB,45436,262,35000.0\r\nCentral African Rep.,SUB-SAHARAN AFRICA,4303356,622984,1100.0\r\nChad,SUB-SAHARAN AFRICA,9944201,1284000,1200.0\r\nChile,LATIN AMER. & CARIB,16134219,756950,9900.0\r\nChina,ASIA (EX. NEAR EAST),1313973713,9596960,5000.0\r\nColombia,LATIN AMER. & CARIB,43593035,1138910,6300.0\r\nComoros,SUB-SAHARAN AFRICA,690948,2170,700.0\r\n"Congo, Dem. Rep.",SUB-SAHARAN AFRICA,62660551,2345410,700.0\r\n"Congo, Repub. of the",SUB-SAHARAN AFRICA,3702314,342000,700.0\r\nCook Islands,OCEANIA,21388,240,5000.0\r\nCosta Rica,LATIN AMER. & CARIB,4075261,51100,9100.0\r\nCote d\'Ivoire,SUB-SAHARAN AFRICA,17654843,322460,1400.0\r\nCroatia,EASTERN EUROPE,4494749,56542,10600.0\r\nCuba,LATIN AMER. & CARIB,11382820,110860,2900.0\r\nCyprus,NEAR EAST,784301,9250,19200.0\r\nCzech Republic,EASTERN EUROPE,10235455,78866,15700.0\r\nDenmark,WESTERN EUROPE,5450661,43094,31100.0\r\nDjibouti,SUB-SAHARAN AFRICA,486530,23000,1300.0\r\nDominica,LATIN AMER. & CARIB,68910,754,5400.0\r\nDominican Republic,LATIN AMER. & CARIB,9183984,48730,6000.0\r\nEast Timor,ASIA (EX. NEAR EAST),1062777,15007,500.0\r\nEcuador,LATIN AMER. & CARIB,13547510,283560,3300.0\r\nEgypt,NORTHERN AFRICA,78887007,1001450,4000.0\r\nEl Salvador,LATIN AMER. & CARIB,6822378,21040,4800.0\r\nEquatorial Guinea,SUB-SAHARAN AFRICA,540109,28051,2700.0\r\nEritrea,SUB-SAHARAN AFRICA,4786994,121320,700.0\r\nEstonia,BALTICS,1324333,45226,12300.0\r\nEthiopia,SUB-SAHARAN AFRICA,74777981,1127127,700.0\r\nFaroe Islands,WESTERN EUROPE,47246,1399,22000.0\r\nFiji,OCEANIA,905949,18270,5800.0\r\nFinland,WESTERN EUROPE,5231372,338145,27400.0\r\nFrance,WESTERN EUROPE,60876136,547030,27600.0\r\nFrench Guiana,LATIN AMER. & CARIB,199509,91000,8300.0\r\nFrench Polynesia,OCEANIA,274578,4167,17500.0\r\nGabon,SUB-SAHARAN AFRICA,1424906,267667,5500.0\r\n"Gambia, The",SUB-SAHARAN AFRICA,1641564,11300,1700.0\r\nGaza Strip,NEAR EAST,1428757,360,600.0\r\nGeorgi ...

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

display(df.head(5),
        df.tail(5))
# Out:
#           Country                Region  ...  Area_sq_mi  GDP_USD_per_capita
# 0     Afghanistan  ASIA (EX. NEAR EAST)  ...      647500               700.0
# 1         Albania        EASTERN EUROPE  ...       28748              4500.0
# 2         Algeria       NORTHERN AFRICA  ...     2381740              6000.0
# 3  American Samoa               OCEANIA  ...         199              8000.0
# 4         Andorra        WESTERN EUROPE  ...         468             19000.0
#
# [5 rows x 5 columns]
#             Country              Region  ...  Area_sq_mi  GDP_USD_per_capita
# 222       West Bank           NEAR EAST  ...        5860               800.0
# 223  Western Sahara     NORTHERN AFRICA  ...      266000                 NaN
# 224           Yemen           NEAR EAST  ...      527970               800.0
# 225          Zambia  SUB-SAHARAN AFRICA  ...      752614               800.0
# 226        Zimbabwe  SUB-SAHARAN AFRICA  ...      390580              1900.0
#
# [5 rows x 5 columns]

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

th = df[df['Country'] == 'Thailand']

th.style.format('{:,}', subset=pd.IndexSlice[:, 'Population':])
# Out:
# <style  type="text/css" >
# </style><table id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Area_sq_mi</th>        <th class="col_heading level0 col4" >GDP_USD_per_capita</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >201</th>
#                         <td id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >Thailand</td>
#                         <td id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002row0_col1" class="data row0 col1" >ASIA (EX. NEAR EAST)</td>
#                         <td id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002row0_col2" class="data row0 col2" >64,631,595</td>
#                         <td id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002row0_col3" class="data row0 col3" >514,000</td>
#                         <td id="T_6450b10a_fe45_11ea_8cfd_0242ac1c0002row0_col4" class="data row0 col4" >7,400.0</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

print(df.Region.unique())
# Out:
# ['ASIA (EX. NEAR EAST)' 'EASTERN EUROPE' 'NORTHERN AFRICA' 'OCEANIA'
#  'WESTERN EUROPE' 'SUB-SAHARAN AFRICA' 'LATIN AMER. & CARIB'
#  'C.W. OF IND. STATES' 'NEAR EAST' 'NORTHERN AMERICA' 'BALTICS']

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

display(df[df['Region'].str.startswith('ASIA')].head(3),
        df[df['Region'].str.endswith('AMERICA')].head(3),
        df[df['Region'].str.find('EUROPE') != -1].head(3))
# Out:
#         Country                Region  ...  Area_sq_mi  GDP_USD_per_capita
# 0   Afghanistan  ASIA (EX. NEAR EAST)  ...      647500               700.0
# 16   Bangladesh  ASIA (EX. NEAR EAST)  ...      144000              1900.0
# 23       Bhutan  ASIA (EX. NEAR EAST)  ...       47000              1300.0
#
# [3 rows x 5 columns]
#       Country            Region  Population  Area_sq_mi  GDP_USD_per_capita
# 22    Bermuda  NORTHERN AMERICA       65773          53             36000.0
# 36     Canada  NORTHERN AMERICA    33098932     9984670             29800.0
# 80  Greenland  NORTHERN AMERICA       56361     2166086             20000.0
#     Country          Region  Population  Area_sq_mi  GDP_USD_per_capita
# 1   Albania  EASTERN EUROPE     3581655       28748              4500.0
# 4   Andorra  WESTERN EUROPE       71201         468             19000.0
# 12  Austria  WESTERN EUROPE     8192880       83870             30000.0

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

idx_max = df['Population'].idxmax()

sr_pop = df.loc[idx_max]

#แนวทางการแสดงผลแบบต่างๆ
display(sr_pop,
        sr_pop.to_frame(),
        sr_pop.to_frame().T)  #หรือใช้ transpose() แทน T
# Out:
# Country                              China
# Region                ASIA (EX. NEAR EAST)
# Population                      1313973713
# Area_sq_mi                         9596960
# GDP_USD_per_capita                    5000
# Name: 42, dtype: object
#                                       42
# Country                            China
# Region              ASIA (EX. NEAR EAST)
# Population                    1313973713
# Area_sq_mi                       9596960
# GDP_USD_per_capita                  5000
#    Country                Region  Population Area_sq_mi GDP_USD_per_capita
# 42   China  ASIA (EX. NEAR EAST)  1313973713    9596960               5000

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

idx_max = df['GDP_USD_per_capita'].idxmax()

sr_gdp = df.loc[idx_max]

display(sr_gdp.to_frame(),
        sr_gdp.to_frame().T)
# Out:
#                                121
# Country                 Luxembourg
# Region              WESTERN EUROPE
# Population                  474413
# Area_sq_mi                    2586
# GDP_USD_per_capita           55100
#         Country          Region Population Area_sq_mi GDP_USD_per_capita
# 121  Luxembourg  WESTERN EUROPE     474413       2586              55100

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

df_sorted_gdp = df.sort_values(by='GDP_USD_per_capita', ascending=False)

df_sorted_gdp.reset_index(inplace=True)

df_h10 = df_sorted_gdp.head(10)

display(df_h10.style.format('{:,.0f}', 
                            subset=pd.IndexSlice[:, 'Population':]))

#ลำดับของประเทศไทย
th_idx = df_sorted_gdp[df_sorted_gdp['Country'] == 'Thailand'].index

print('Thailand rank:', th_idx[0] + 1)
# Out:
# <style  type="text/css" >
# </style><table id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Country</th>        <th class="col_heading level0 col2" >Region</th>        <th class="col_heading level0 col3" >Population</th>        <th class="col_heading level0 col4" >Area_sq_mi</th>        <th class="col_heading level0 col5" >GDP_USD_per_capita</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >121</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row0_col1" class="data row0 col1" >Luxembourg</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row0_col2" class="data row0 col2" >WESTERN EUROPE</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row0_col3" class="data row0 col3" >474,413</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row0_col4" class="data row0 col4" >2,586</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row0_col5" class="data row0 col5" >55,100</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >154</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row1_col1" class="data row1 col1" >Norway</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row1_col2" class="data row1 col2" >WESTERN EUROPE</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row1_col3" class="data row1 col3" >4,610,820</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row1_col4" class="data row1 col4" >323,802</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row1_col5" class="data row1 col5" >37,800</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >214</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row2_col1" class="data row2 col1" >United States</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row2_col2" class="data row2 col2" >NORTHERN AMERICA</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row2_col3" class="data row2 col3" >298,444,215</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row2_col4" class="data row2 col4" >9,631,420</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row2_col5" class="data row2 col5" >37,800</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >22</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row3_col1" class="data row3 col1" >Bermuda</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row3_col2" class="data row3 col2" >NORTHERN AMERICA</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row3_col3" class="data row3 col3" >65,773</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row3_col4" class="data row3 col4" >53</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row3_col5" class="data row3 col5" >36,000</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >38</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row4_col1" class="data row4 col1" >Cayman Islands</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row4_col2" class="data row4 col2" >LATIN AMER. & CARIB</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row4_col3" class="data row4 col3" >45,436</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row4_col4" class="data row4 col4" >262</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row4_col5" class="data row4 col5" >35,000</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >177</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row5_col1" class="data row5 col1" >San Marino</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row5_col2" class="data row5 col2" >WESTERN EUROPE</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row5_col3" class="data row5 col3" >29,251</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row5_col4" class="data row5 col4" >61</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row5_col5" class="data row5 col5" >34,600</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >196</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row6_col1" class="data row6 col1" >Switzerland</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row6_col2" class="data row6 col2" >WESTERN EUROPE</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row6_col3" class="data row6 col3" >7,523,934</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row6_col4" class="data row6 col4" >41,290</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row6_col5" class="data row6 col5" >32,700</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >54</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row7_col1" class="data row7 col1" >Denmark</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row7_col2" class="data row7 col2" >WESTERN EUROPE</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row7_col3" class="data row7 col3" >5,450,661</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row7_col4" class="data row7 col4" >43,094</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row7_col5" class="data row7 col5" >31,100</td>
#             </tr>
#             <tr>
#                         <th id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >93</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row8_col1" class="data row8 col1" >Iceland</td>
#                         <td id="T_a98811fa_fe45_11ea_8cfd_0242ac1c0002row8_col2" class="data row8 col2" >WESTERN EUROPE</td>
# Thailand rank: 94

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

df = df.head(5)

df.insert(5, 'GDP_USD', df['Population'] * df['GDP_USD_per_capita'])     
df.insert(6, 'Pop_density_per_sq_mi', df['Population'] / df['Area_sq_mi'])

#display(df)

style = df.style.format('{:,.0f}', 
                        subset=pd.IndexSlice[:, 'Population':'GDP_USD'])

style.format({'Pop_density_per_sq_mi':'{:,.2f}'})

display(style)
# Out:
# <style  type="text/css" >
# </style><table id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Area_sq_mi</th>        <th class="col_heading level0 col4" >GDP_USD_per_capita</th>        <th class="col_heading level0 col5" >GDP_USD</th>        <th class="col_heading level0 col6" >Pop_density_per_sq_mi</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >Afghanistan</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col1" class="data row0 col1" >ASIA (EX. NEAR EAST)</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col2" class="data row0 col2" >31,056,997</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col3" class="data row0 col3" >647,500</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col4" class="data row0 col4" >700</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col5" class="data row0 col5" >21,739,897,900</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row0_col6" class="data row0 col6" >47.96</td>
#             </tr>
#             <tr>
#                         <th id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >Albania</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col1" class="data row1 col1" >EASTERN EUROPE</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col2" class="data row1 col2" >3,581,655</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col3" class="data row1 col3" >28,748</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col4" class="data row1 col4" >4,500</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col5" class="data row1 col5" >16,117,447,500</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row1_col6" class="data row1 col6" >124.59</td>
#             </tr>
#             <tr>
#                         <th id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >Algeria</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col1" class="data row2 col1" >NORTHERN AFRICA</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col2" class="data row2 col2" >32,930,091</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col3" class="data row2 col3" >2,381,740</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col4" class="data row2 col4" >6,000</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col5" class="data row2 col5" >197,580,546,000</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row2_col6" class="data row2 col6" >13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >American Samoa</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col1" class="data row3 col1" >OCEANIA</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col2" class="data row3 col2" >57,794</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col3" class="data row3 col3" >199</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col4" class="data row3 col4" >8,000</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col5" class="data row3 col5" >462,352,000</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row3_col6" class="data row3 col6" >290.42</td>
#             </tr>
#             <tr>
#                         <th id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >Andorra</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col1" class="data row4 col1" >WESTERN EUROPE</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col2" class="data row4 col2" >71,201</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col3" class="data row4 col3" >468</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col4" class="data row4 col4" >19,000</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col5" class="data row4 col5" >1,352,819,000</td>
#                         <td id="T_afbcc6e2_fe45_11ea_8cfd_0242ac1c0002row4_col6" class="data row4 col6" >152.14</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

df = df.head(5)

a = lambda frame: frame['Population'] * frame['GDP_USD_per_capita']
b = lambda frame: frame['Population'] / frame['Area_sq_mi']

df2 = df.assign(GDP_USD=a, Pop_density_per_sq_mi=b)
                
#display(df2)
    
style = df2.style.format('{:,.0f}', 
                         subset=pd.IndexSlice[:, 'Population':'GDP_USD'])

style.format({'Pop_density_per_sq_mi':'{:,.2f}'})

display(style)
# Out:
# <style  type="text/css" >
# </style><table id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Area_sq_mi</th>        <th class="col_heading level0 col4" >GDP_USD_per_capita</th>        <th class="col_heading level0 col5" >GDP_USD</th>        <th class="col_heading level0 col6" >Pop_density_per_sq_mi</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >Afghanistan</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col1" class="data row0 col1" >ASIA (EX. NEAR EAST)</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col2" class="data row0 col2" >31,056,997</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col3" class="data row0 col3" >647,500</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col4" class="data row0 col4" >700</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col5" class="data row0 col5" >21,739,897,900</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row0_col6" class="data row0 col6" >47.96</td>
#             </tr>
#             <tr>
#                         <th id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >Albania</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col1" class="data row1 col1" >EASTERN EUROPE</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col2" class="data row1 col2" >3,581,655</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col3" class="data row1 col3" >28,748</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col4" class="data row1 col4" >4,500</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col5" class="data row1 col5" >16,117,447,500</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row1_col6" class="data row1 col6" >124.59</td>
#             </tr>
#             <tr>
#                         <th id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >Algeria</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col1" class="data row2 col1" >NORTHERN AFRICA</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col2" class="data row2 col2" >32,930,091</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col3" class="data row2 col3" >2,381,740</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col4" class="data row2 col4" >6,000</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col5" class="data row2 col5" >197,580,546,000</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row2_col6" class="data row2 col6" >13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >American Samoa</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col1" class="data row3 col1" >OCEANIA</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col2" class="data row3 col2" >57,794</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col3" class="data row3 col3" >199</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col4" class="data row3 col4" >8,000</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col5" class="data row3 col5" >462,352,000</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row3_col6" class="data row3 col6" >290.42</td>
#             </tr>
#             <tr>
#                         <th id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >Andorra</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col1" class="data row4 col1" >WESTERN EUROPE</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col2" class="data row4 col2" >71,201</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col3" class="data row4 col3" >468</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col4" class="data row4 col4" >19,000</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col5" class="data row4 col5" >1,352,819,000</td>
#                         <td id="T_b58d7b84_fe45_11ea_8cfd_0242ac1c0002row4_col6" class="data row4 col6" >152.14</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

g = df.groupby(['Region'])[['Population', 'Area_sq_mi']].sum()

g = g.add_prefix('sum_')

display(g.style.format('{:,}'))
# Out:
# <style  type="text/css" >
# </style><table id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum_Population</th>        <th class="col_heading level0 col1" >sum_Area_sq_mi</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >ASIA (EX. NEAR EAST)</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >3,687,982,236</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row0_col1" class="data row0 col1" >23,096,712</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row1" class="row_heading level0 row1" >BALTICS</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >7,184,974</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row1_col1" class="data row1 col1" >175,015</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row2" class="row_heading level0 row2" >C.W. OF IND. STATES</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >280,081,548</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row2_col1" class="data row2 col1" >22,100,843</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" >EASTERN EUROPE</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >119,914,717</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row3_col1" class="data row3 col1" >1,152,222</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row4" class="row_heading level0 row4" >LATIN AMER. & CARIB</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >561,824,599</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row4_col1" class="data row4 col1" >20,544,084</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row5" class="row_heading level0 row5" >NEAR EAST</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >195,068,377</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row5_col1" class="data row5 col1" >4,355,586</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" >NORTHERN AFRICA</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >161,407,133</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row6_col1" class="data row6 col1" >6,018,890</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row7" class="row_heading level0 row7" >NORTHERN AMERICA</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >331,672,307</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row7_col1" class="data row7 col1" >21,782,471</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row8" class="row_heading level0 row8" >OCEANIA</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >33,131,662</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row8_col1" class="data row8 col1" >8,519,812</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row9" class="row_heading level0 row9" >SUB-SAHARAN AFRICA</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row9_col0" class="data row9 col0" >749,437,000</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row9_col1" class="data row9 col1" >24,341,406</td>
#             </tr>
#             <tr>
#                         <th id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002level0_row10" class="row_heading level0 row10" >WESTERN EUROPE</th>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row10_col0" class="data row10 col0" >396,339,998</td>
#                         <td id="T_dfc79cd6_fe45_11ea_8cfd_0242ac1c0002row10_col1" class="data row10 col1" >3,710,478</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

g = df.groupby(['Region']).agg({'Population':[max, min], 
                                'GDP_USD_per_capita':[max, min]})

display(g.style.format('{:,}'))
# Out:
# <style  type="text/css" >
# </style><table id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>Population</th>        <th class="col_heading level0 col2" colspan=2>GDP_USD_per_capita</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >max</th>        <th class="col_heading level1 col1" >min</th>        <th class="col_heading level1 col2" >max</th>        <th class="col_heading level1 col3" >min</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" >ASIA (EX. NEAR EAST)</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >1,313,973,713</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row0_col1" class="data row0 col1" >359,008</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row0_col2" class="data row0 col2" >28,800.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row0_col3" class="data row0 col3" >500.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row1" class="row_heading level0 row1" >BALTICS</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >3,585,906</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row1_col1" class="data row1 col1" >1,324,333</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row1_col2" class="data row1 col2" >12,300.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row1_col3" class="data row1 col3" >10,200.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row2" class="row_heading level0 row2" >C.W. OF IND. STATES</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >142,893,540</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row2_col1" class="data row2 col1" >2,976,372</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row2_col2" class="data row2 col2" >8,900.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row2_col3" class="data row2 col3" >1,000.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" >EASTERN EUROPE</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >38,536,869</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row3_col1" class="data row3 col1" >2,010,347</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row3_col2" class="data row3 col2" >19,000.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row3_col3" class="data row3 col3" >2,200.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row4" class="row_heading level0 row4" >LATIN AMER. & CARIB</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >188,078,227</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row4_col1" class="data row4 col1" >9,439</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row4_col2" class="data row4 col2" >35,000.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row4_col3" class="data row4 col3" >1,600.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row5" class="row_heading level0 row5" >NEAR EAST</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >70,413,958</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row5_col1" class="data row5 col1" >698,585</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row5_col2" class="data row5 col2" >23,200.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row5_col3" class="data row5 col3" >600.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" >NORTHERN AFRICA</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >78,887,007</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row6_col1" class="data row6 col1" >273,008</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row6_col2" class="data row6 col2" >6,900.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row6_col3" class="data row6 col3" >4,000.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row7" class="row_heading level0 row7" >NORTHERN AMERICA</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >298,444,215</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row7_col1" class="data row7 col1" >7,026</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row7_col2" class="data row7 col2" >37,800.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row7_col3" class="data row7 col3" >6,900.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row8" class="row_heading level0 row8" >OCEANIA</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >20,264,082</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row8_col1" class="data row8 col1" >11,810</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row8_col2" class="data row8 col2" >29,000.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row8_col3" class="data row8 col3" >800.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row9" class="row_heading level0 row9" >SUB-SAHARAN AFRICA</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row9_col0" class="data row9 col0" >131,859,731</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row9_col1" class="data row9 col1" >7,502</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row9_col2" class="data row9 col2" >11,400.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row9_col3" class="data row9 col3" >500.0</td>
#             </tr>
#             <tr>
#                         <th id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002level0_row10" class="row_heading level0 row10" >WESTERN EUROPE</th>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row10_col0" class="data row10 col0" >82,422,299</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row10_col1" class="data row10 col1" >27,928</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row10_col2" class="data row10 col2" >55,100.0</td>
#                         <td id="T_06dd8a60_fe46_11ea_8cfd_0242ac1c0002row10_col3" class="data row10 col3" >17,500.0</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

df.pivot_table(aggfunc=[max, min],
               values=['Population', 'GDP_USD_per_capita'],
               index=['Region'],
               margins=False)
# Out:
#                                     max  ...        min
#                      GDP_USD_per_capita  ... Population
# Region                                   ...
# ASIA (EX. NEAR EAST)            28800.0  ...     359008
# BALTICS                         12300.0  ...    1324333
# C.W. OF IND. STATES              8900.0  ...    2976372
# EASTERN EUROPE                  19000.0  ...    2010347
# LATIN AMER. & CARIB             35000.0  ...       9439
# NEAR EAST                       23200.0  ...     698585
# NORTHERN AFRICA                  6900.0  ...     273008
# NORTHERN AMERICA                37800.0  ...       7026
# OCEANIA                         29000.0  ...      11810
# SUB-SAHARAN AFRICA              11400.0  ...       7502
# WESTERN EUROPE                  55100.0  ...      27928
#
# [11 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv('countries_info.csv')

#เรียงลำดับข้อมูลจากมากไปหาน้อย โดยใช้คอลัมน์เป้าหมายที่หาค่าสูงสุดเป็นเกณฑ์
df_sorted = df.sort_values(by='GDP_USD_per_capita', ascending=False)

#แบ่งกลุ่มตามภูมิภาคแล้วเลือกข้อมูล 3 ลำดับแรกของแต่ละกลุ่ม
df_grp_by_reg = df_sorted.groupby(['Region']).head(3)

#display(df_grp_by_reg)

#จัดกลุ่มอีกครั้ง โดยใช้ภูมิภาคและประเทศในการจัดกลุ่ม
#แล้วแสดงผลรวมของแต่ละกลุ่ม ในแบบ Aggregate Function 
#เพื่อหาผลรวมเฉพาะคอลัมน์ GDP 
g = df_grp_by_reg \
        .groupby(['Region', 'Country']) \
        .agg({'GDP_USD_per_capita':max}) \
        .add_prefix('max_')

#หรือแบบนี้ก็ได้
#g = df_grp_by_reg \
#        .groupby(['Region', 'Country'])[['GDP_USD_per_capita']] \
#        .max().add_prefix('max_')

#ถ้าต้องการแยกแสดงผลทีละส่วน พร้อมจัดสไตล์
display(g[:9].style.format('{:,}'), 
        g[9:18].style.format('{:,}'),
        g[18:27].style.format('{:,}'),
        g[27:].style.format('{:,}'))
# Out:
# <style  type="text/css" >
# </style><table id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>ASIA (EX. NEAR EAST)</th>
#                         <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row0" class="row_heading level1 row0" >Hong Kong</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >28,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row1" class="row_heading level1 row1" >Japan</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >28,200.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row2" class="row_heading level1 row2" >Singapore</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >23,700.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" rowspan=3>BALTICS</th>
#                         <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row3" class="row_heading level1 row3" >Estonia</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >12,300.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row4" class="row_heading level1 row4" >Latvia</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >10,200.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row5" class="row_heading level1 row5" >Lithuania</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >11,400.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" rowspan=3>C.W. OF IND. STATES</th>
#                         <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row6" class="row_heading level1 row6" >Belarus</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >6,100.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row7" class="row_heading level1 row7" >Kazakhstan</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >6,300.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002level1_row8" class="row_heading level1 row8" >Russia</th>
#                         <td id="T_23d503c8_fe46_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >8,900.0</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>EASTERN EUROPE</th>
#                         <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row0" class="row_heading level1 row0" >Czech Republic</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >15,700.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row1" class="row_heading level1 row1" >Hungary</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >13,900.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row2" class="row_heading level1 row2" >Slovenia</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >19,000.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" rowspan=3>LATIN AMER. & CARIB</th>
#                         <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row3" class="row_heading level1 row3" >Aruba</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >28,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row4" class="row_heading level1 row4" >Cayman Islands</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >35,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row5" class="row_heading level1 row5" >Virgin Islands</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >17,200.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" rowspan=3>NEAR EAST</th>
#                         <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row6" class="row_heading level1 row6" >Israel</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >19,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row7" class="row_heading level1 row7" >Qatar</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >21,500.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002level1_row8" class="row_heading level1 row8" >United Arab Emirates</th>
#                         <td id="T_23d586fe_fe46_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >23,200.0</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>NORTHERN AFRICA</th>
#                         <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row0" class="row_heading level1 row0" >Algeria</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >6,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row1" class="row_heading level1 row1" >Libya</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >6,400.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row2" class="row_heading level1 row2" >Tunisia</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >6,900.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" rowspan=3>NORTHERN AMERICA</th>
#                         <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row3" class="row_heading level1 row3" >Bermuda</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >36,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row4" class="row_heading level1 row4" >Canada</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >29,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row5" class="row_heading level1 row5" >United States</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >37,800.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level0_row6" class="row_heading level0 row6" rowspan=3>OCEANIA</th>
#                         <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row6" class="row_heading level1 row6" >Australia</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row6_col0" class="data row6 col0" >29,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row7" class="row_heading level1 row7" >Guam</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row7_col0" class="data row7 col0" >21,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002level1_row8" class="row_heading level1 row8" >New Zealand</th>
#                         <td id="T_23d62d52_fe46_11ea_8cfd_0242ac1c0002row8_col0" class="data row8 col0" >21,600.0</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_GDP_USD_per_capita</th>    </tr>    <tr>        <th class="index_name level0" >Region</th>        <th class="index_name level1" >Country</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>SUB-SAHARAN AFRICA</th>
#                         <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level1_row0" class="row_heading level1 row0" >Botswana</th>
#                         <td id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002row0_col0" class="data row0 col0" >9,000.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level1_row1" class="row_heading level1 row1" >Mauritius</th>
#                         <td id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002row1_col0" class="data row1 col0" >11,400.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level1_row2" class="row_heading level1 row2" >South Africa</th>
#                         <td id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002row2_col0" class="data row2 col0" >10,700.0</td>
#             </tr>
#             <tr>
#                         <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level0_row3" class="row_heading level0 row3" rowspan=3>WESTERN EUROPE</th>
#                         <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level1_row3" class="row_heading level1 row3" >Luxembourg</th>
#                         <td id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002row3_col0" class="data row3 col0" >55,100.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level1_row4" class="row_heading level1 row4" >Norway</th>
#                         <td id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002row4_col0" class="data row4 col0" >37,800.0</td>
#             </tr>
#             <tr>
#                                 <th id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002level1_row5" class="row_heading level1 row5" >San Marino</th>
#                         <td id="T_23d6da0e_fe46_11ea_8cfd_0242ac1c0002row5_col0" class="data row5 col0" >34,600.0</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data-sci\\countries_info.csv')

countries = ['Thailand', 'Malaysia', 'Singapore', 
             'Indonesia', 'Vietnam', 'Philippines']
gdps = []

for i, c in enumerate(countries):
    idx = df[df.Country == countries[i]].index
    g = df.at[idx[0], 'GDP_USD_per_capita']
    gdps.append(g)

plt.bar(countries, gdps, color=['r', 'b', 'g', 'm', 'y', 'k'])
plt.xticks(rotation=60)
plt.title('ASEAN GDP per capita (USD)')
plt.show()
